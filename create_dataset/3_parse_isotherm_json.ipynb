# %%
import os
import pickle
import glob
import json

import numpy as np
import pandas as pd
from itertools import combinations
from scipy.optimize import curve_fit

from itertools import combinations
from scipy.optimize import curve_fit

import ipywidgets as widgets

# %matplotlib inline

# %% [markdown]
# # Превращаем данные в .json в DataFrame

# %%
# %%time

isotherms_data_folder = r'downloaded'
total = []

for json_file in glob.glob(isotherms_data_folder + r'\*.json'):
#     print(json_file)

    #read
    with open(json_file, 'r') as json_inp:
        json_data = json.load(json_inp)

    # check if only single substance was adsorbed
    if json_data['isotherm_data'][0]['species_data'][0]['composition'] != 1:
        continue
    
    category = json_data['category']
    adsorbent = json_data['adsorbent']['name']
    adsorbate = json_data['adsorbates'][0]['name']
    temperature = json_data['temperature']
    doi = json_data['DOI']
    p_units = json_data['pressureUnits']
    ads_units = json_data['adsorptionUnits']
    pressure = [d['pressure'] for d in json_data['isotherm_data']]
    adsorption = [d['total_adsorption'] for d in json_data['isotherm_data']]

    total.append([doi, category,
                  adsorbent, adsorbate, temperature,
                  p_units, ads_units, pressure, adsorption])
# Out:
# Wall time: 1.75 s

# %%
df_sum = pd.DataFrame(total, columns=['doi', 'category',
                                      'adsorbent', 'adsorbate', 'temperature',
                                      'p_units', 'ads_units', 'pressure', 'adsorption'])

# %% [markdown]
# # Все возможные величины адсорбции в данном датасете

# %% [markdown]
# Из всех видов были выбраны `mmol/g`, `cm3(STP)/g`, `mg/g`, `ml/g`, `mol/g`, `mmol/kg`. В следующем блоке показано количество разных величин.

# %%
df_sum['ads_units'].value_counts()
# Out:
# mmol/g                        1558
# cm3(STP)/g                     790
# wt%                            143
# molecules/unitcell             110
# mg/g                            98
# ml/g                            44
# cm3(STP)/cm3                    38
# mmol/cm3                        38
# mol/mol                         18
# mol/m3                          16
# mol/l                           10
# mg/m2                            8
# kmol/m3                          7
# molecules/cage                   6
#                                  6
# cm3/m2                           5
# molecules/Cu2 unit               3
# molecules/Rh2 unit               3
# molecules/8 unit cells           3
# Guest molecules per Cu ion       2
# g/l                              2
# mmol/m2                          2
# molecules/nm2                    2
# mol/g                            2
# mmol/kg                          1
# molecules/formula unit           1
# mol/m2                           1
# molecules/pore                   1
# Name: ads_units, dtype: int64

# %% [markdown]
# # Блок перевода величин

# %% [markdown]
# Из всего перечня величин было решено оставить самую распространенную как основную, и по возможности перевести остальные.

# %%
df_ads = df_sum.copy()
chosen_ads_units = list(df_ads[df_ads['ads_units'] == 'mmol/g'].index) \
                 + list(df_ads[df_ads['ads_units'] == 'cm3(STP)/g'].index) \
                 + list(df_ads[df_ads['ads_units'] == 'mg/g'].index) \
                 + list(df_ads[df_ads['ads_units'] == 'ml/g'].index) \
                 + list(df_ads[df_ads['ads_units'] == 'mol/g'].index) \
                 + list(df_ads[df_ads['ads_units'] == 'mmol/kg'].index) 
df_ads = df_ads[df_ads.index.isin(chosen_ads_units)]
df_ads['ads_units'].value_counts()
# Out:
# mmol/g        1558
# cm3(STP)/g     790
# mg/g            98
# ml/g            44
# mol/g            2
# mmol/kg          1
# Name: ads_units, dtype: int64

# %% [markdown]
# Из всего перечня величин можно перевести 5 в `mmol/g`. В следующем блоке - код перевода величин. Для перевода из:
#
# - `cm3(STP)/g` или `ml/g` в `mmol/g` нужно поделить на 22,4
# - `mg/g` в `mmol/g` нужно поделить на 44,0
# - `mol/g` в `mmol/g` нужно умножить на 1000
# - `mmol/kg` в `mmol/g` нужно поделить на 1000

# %%
df_prep = df_ads.dropna()
for i, row in df_prep.iterrows():
    if row['ads_units'] == 'cm3(STP)/g' or row['ads_units'] == 'ml/g':
        try:
            new_value = np.true_divide(row['adsorption'], 22.4)
        except:
            new_value = np.nan
        df_prep.at[i,'ads_units'] = 'mmol/g'
        df_prep.at[i,'adsorption'] = new_value
    elif row['ads_units'] == 'mg/g':
        try:
            new_value = np.true_divide(row['adsorption'], 44.0)
        except:
            new_value = np.nan
        df_prep.at[i,'ads_units'] = 'mmol/g'
        df_prep.at[i,'adsorption'] = new_value
    elif row['ads_units'] == 'mol/g':
        try:
            new_value = np.multiply(row['adsorption'], 1000.0)
        except:
            new_value = np.nan
        df_prep.at[i,'ads_units'] = 'mmol/g'
        df_prep.at[i,'adsorption'] = new_value
    elif row['ads_units'] == 'mmol/kg':
        try:
            new_value = np.true_divide(row['adsorption'], 1000.0)
        except:
            new_value = np.nan
        df_prep.at[i,'ads_units'] = 'mmol/g'
        df_prep.at[i,'adsorption'] = new_value    
    elif row['ads_units'] == 'mmol/g':
        if None in row['adsorption']:
            df_prep.at[i,'adsorption'] = np.nan
df_prep = df_prep.dropna()
df_prep['ads_units'].value_counts()
# Out:
# mmol/g    2160
# Name: ads_units, dtype: int64

# %% [markdown]
# # DataFrame после перевода величин (первые 50 записей)

# %%
df_prep.reset_index(inplace=True, drop=True)
df_prep.head(50)
# Out:
#                        doi category             adsorbent       adsorbate  \
# 0   10.1002/adfm.201200084                 NH2-MIL-53(Al)  Carbon Dioxide
# 1   10.1002/adfm.201200084                 NH2-MIL-53(Al)  Carbon Dioxide
# 2   10.1002/adfm.201300071                           CCT1  Carbon Dioxide
# 3   10.1002/adfm.201300071                           CCT1  Carbon Dioxide
# 4   10.1002/adfm.201300071                             CT  Carbon Dioxide
# 5   10.1002/adfm.201300071                           CCT1  Carbon Dioxide
# 6   10.1002/adfm.201300071                           CCT1  Carbon Dioxide
# 7   10.1002/adfm.201300071                           CCT1  Carbon Dioxide
# 8   10.1002/adfm.201300071                           CCT1  Carbon Dioxide
# 9   10.1002/adfm.201300071                             CT  Carbon Dioxide
# 10  10.1002/adfm.201300071                             CT  Carbon Dioxide
# 11  10.1002/adfm.201300071                           CCT1  Carbon Dioxide
# 12  10.1002/adfm.201301178                   Zn(OPE) 2H2O  Carbon Dioxide
# 13  10.1002/adfm.201502069      exp  PAF-1(Photoswitched)  Carbon Dioxide
# 14  10.1002/adma.200601983                          CUK-1  Carbon Dioxide
# 15  10.1002/adma.200601983                        CMS-T3A  Carbon Dioxide
# 16  10.1002/adma.200601983                        CMS-T3A  Carbon Dioxide
# 17  10.1002/adma.200601983                          CUK-1  Carbon Dioxide
# 18  10.1002/adma.200602645                     MIL-53(Cr)  Carbon Dioxide
# 19  10.1002/adma.200702605                   Zn(2-2H)*H2O  Carbon Dioxide
# 20  10.1002/adma.200802485                          CPP-8  Carbon Dioxide
# 21  10.1002/adma.200802485                          CPP-7  Carbon Dioxide
# 22  10.1002/adma.200802485                          CPP-6  Carbon Dioxide
# 23  10.1002/adma.201400428                 Cu3(BTC)2@TiO2  Carbon Dioxide
# 24  10.1002/adma.201400428                          CuBTC  Carbon Dioxide
# 25  10.1002/adma.201403827      exp                 CuBTC  Carbon Dioxide
# 26  10.1002/adma.201403827      exp                 CuBTC  Carbon Dioxide
# 27  10.1002/adma.201403827      exp         HKUST-1@PS_63  Carbon Dioxide
# 28  10.1002/adma.201403827      exp         HKUST-1@PS_63  Carbon Dioxide
# 29  10.1002/adma.201403827      exp                    PS  Carbon Dioxide
# 30  10.1002/adma.201605826      exp                DATPIM  Carbon Dioxide
# 31  10.1002/adma.201605826      exp                 PIM-1  Carbon Dioxide
# 32       10.1002/Aic.11865                        Soc-MOF  Carbon Dioxide
# 33       10.1002/Aic.13970                       ED-ZIF-8  Carbon Dioxide
# 34       10.1002/Aic.13970                          ZIF-8  Carbon Dioxide
# 35       10.1002/Aic.13970                          ZIF-8  Carbon Dioxide
# 36       10.1002/Aic.13970                          ZIF-8  Carbon Dioxide
# 37       10.1002/Aic.13970                       ED-ZIF-8  Carbon Dioxide
# 38       10.1002/Aic.13970                          ZIF-8  Carbon Dioxide
# 39       10.1002/Aic.13970                          ZIF-8  Carbon Dioxide
# 40       10.1002/Aic.13970                       ED-ZIF-8  Carbon Dioxide
# 41       10.1002/Aic.13970                       ED-ZIF-8  Carbon Dioxide
# 42       10.1002/Aic.13970                       ED-ZIF-8  Carbon Dioxide
# 43       10.1002/Aic.14467                            DDR  Carbon Dioxide
# 44       10.1002/Aic.14467                         MIL-47  Carbon Dioxide
# 45       10.1002/Aic.14467                         MIL-47  Carbon Dioxide
# 46       10.1002/Aic.14467                        MOF-177  Carbon Dioxide
# 47       10.1002/Aic.14467                        MOF-177  Carbon Dioxide
# 48       10.1002/Aic.14467                        MOF-177  Carbon Dioxide
# 49       10.1002/Aic.14467                      Mg-MOF-74  Carbon Dioxide
#
#     temperature p_units ads_units  \
# 0           273     bar    mmol/g
# 1           298     bar    mmol/g
# 2           273     bar    mmol/g
# 3           273     bar    mmol/g
# 4           273     bar    mmol/g
# 5           273     bar    mmol/g
# 6           273     bar    mmol/g
# 7           273     bar    mmol/g
# 8           273     bar    mmol/g
# 9           273     bar    mmol/g
# 10          273     bar    mmol/g
# 11          273     bar    mmol/g
# 12          195     bar    mmol/g
# 13          303     bar    mmol/g
# 14          196     bar    mmol/g
# 15          196     bar    mmol/g
# 16          298     bar    mmol/g
# 17          298     bar    mmol/g
# 18          304     bar    mmol/g
# 19          258     bar    mmol/g
# 20          195     bar    mmol/g
# 21          195     bar    mmol/g
# 22          195     bar    mmol/g
# 23          298     bar    mmol/g
# 24          298     bar    mmol/g
# 25          295     bar    mmol/g
# 26          295     bar    mmol/g
# 27          295     bar    mmol/g
# 28          295     bar    mmol/g
# 29          295     bar    mmol/g
# 30          298     bar    mmol/g
# 31          298     bar    mmol/g
# 32          298     bar    mmol/g
# 33          328     bar    mmol/g
# 34          298     bar    mmol/g
# 35          298     bar    mmol/g
# 36          308     bar    mmol/g
# 37          298     bar    mmol/g
# 38          318     bar    mmol/g
# 39          328     bar    mmol/g
# 40          298     bar    mmol/g
# 41          308     bar    mmol/g
# 42          318     bar    mmol/g
# 43          298     bar    mmol/g
# 44          298     bar    mmol/g
# 45          298     bar    mmol/g
# 46          298     bar    mmol/g
# 47          298     bar    mmol/g
# 48          298     bar    mmol/g
# 49          298     bar    mmol/g
#
#                                              pressure  \
# 0   [0.42318, 0.676969, 1.01993, 1.36288, 1.70644,...
# 1   [0.678881, 1.35654, 1.86693, 2.54398, 3.22102,...
# 2   [0.0126608, 0.0422383, 0.0746326, 0.112661, 0....
# 3   [0.0182946, 0.0408298, 0.0816749, 0.129562, 0....
# 4   [0.0408298, 0.0999848, 0.161957, 0.218295, 0.2...
# 5   [0.0112524, 0.0816749, 0.161957, 0.221112, 0.2...
# 6   [0.0112524, 0.078858, 0.130971, 0.192943, 0.28...
# 7   [0.0689988, 0.15914, 0.221112, 0.280266, 0.339...
# 8   [0.0422383, 0.0999848, 0.161957, 0.250689, 0.3...
# 9   [0.02252, 0.0661819, 0.160548, 0.253506, 0.345...
# 10  [0.0718157, 0.132379, 0.223928, 0.309844, 0.40...
# 11  [0.0140693, 0.0422383, 0.0802664, 0.112661, 0....
# 12  [0.011591, 0.0125803, 0.0222627, 0.0260398, 0....
# 13  [0, 0.050381, 0.081601, 0.108699, 0.128167, 0....
# 14  [0.00302147, 0.00604294, 0.0120859, 0.0241718,...
# 15  [0.00381528, 0.0185494, 0.0623471, 0.120634, 0...
# 16  [0.00848082, 0.090245, 0.229363, 0.359861, 0.5...
# 17  [0.02517, 0.135289, 0.239115, 0.364965, 0.5096...
# 18  [0.14003, 0.273866, 0.325569, 0.365962, 0.4561...
# 19  [0.041306, 0.108469, 0.18258, 0.298378, 0.4327...
# 20  [0.00953647, 0.0190729, 0.0309935, 0.0667553, ...
# 21  [0.00953647, 0.0190729, 0.0309935, 0.0429141, ...
# 22  [0.00953647, 0.0166888, 0.0286094, 0.04053, 0....
# 23  [2.39868, 4.16471, 5.67958, 7.57237, 9.21284, ...
# 24  [1.01098, 2.52784, 4.29665, 5.93908, 7.58109, ...
# 25  [0.006753, 0.035533, 0.053299, 0.05566, 0.0843...
# 26  [0.006753, 0.035533, 0.053299, 0.05566, 0.0843...
# 27  [0.002262, 0.006628, 0.033112, 0.055237, 0.057...
# 28  [0.002262, 0.006628, 0.033112, 0.055237, 0.057...
# 29  [0.002268, 0.006582, 0.028608, 0.055027, 0.081...
# 30  [0.008999, 0.012932, 0.020798, 0.030931, 0.041...
# 31  [0.010119, 0.021332, 0.032664, 0.04213, 0.0527...
# 32  [0.251391, 0.316938, 1.10349, 2.08669, 3.06988...
# 33  [0.437049, 1.18705, 3.14538, 5.02038, 8.14538,...
# 34  [0.103716, 0.395382, 1.02038, 1.93705, 4.97872...
# 35  [0.395382, 0.895382, 2.56205, 5.02038, 7.18705...
# 36  [0.103716, 0.437049, 1.02038, 3.68705, 4.93705...
# 37  [0.174459, 0.624459, 1.17446, 3.12446, 5.02446...
# 38  [0.0203823, 0.603716, 1.39538, 2.52038, 5.1037...
# 39  [0.0203823, 0.520382, 1.31205, 5.14538, 10.062...
# 40  [0.395382, 0.562049, 0.937049, 2.89538, 4.9370...
# 41  [0.395382, 0.937049, 2.93705, 5.02038, 8.02038...
# 42  [0.520382, 1.06205, 3.06205, 5.06205, 8.10372,...
# 43  [0.0594233, 0.29862, 0.437467, 0.516775, 0.615...
# 44  [9.65041e-05, 0.0438129, 0.0919443, 0.196893, ...
# 45  [4.82521e-05, 0.0437888, 0.100654, 0.192478, 0...
# 46  [2.43392e-05, 0.044273, 0.100545, 0.197123, 0....
# 47  [0.0646206, 0.108796, 0.161052, 0.189262, 0.22...
# 48                             [-0.00391861, 1.00506]
# 49  [0.00420168, 0.012605, 0.0336134, 0.0588235, 0...
#
#                                            adsorption
# 0   [0.3864669642857143, 0.6226428571428572, 0.772...
# 1   [0.09775803571428571, 0.17922321428571428, 0.2...
# 2   [0.098115625, 0.2917776785714286, 0.4275924107...
# 3   [0.09057053571428571, 0.2188401785714286, 0.33...
# 4   [0.18865892857142857, 0.34710982142857144, 0.4...
# 5   [0.098115625, 0.31944375, 0.45777232142857144,...
# 6   [0.098115625, 0.26159642857142856, 0.349625, 0...
# 7   [0.08554017857142858, 0.17859866071428573, 0.2...
# 8   [0.030208303571428573, 0.07547991071428571, 0....
# 9   [0.04278375, 0.098115625, 0.16853839285714287,...
# 10  [0.0075725, 0.005057410714285715, 0.0126026785...
# 11  [0.1081763392857143, 0.3722607142857143, 0.535...
# 12  [0.0010337410714285715, 0.08425, 0.16824151785...
# 13  [0, 0.026616, 0.069201, 0.079848, 0.101141, 0....
# 14  [1.8130803571428573, 3.2840714285714285, 5.644...
# 15  [2.2269642857142857, 4.661071428571429, 6.9916...
# 16  [0.01936433035714286, 0.4352419642857143, 0.77...
# 17  [0.26396294642857143, 1.0234375, 1.63455803571...
# 18  [0.204187, 0.996459, 0.587236, 1.25191, 1.6863...
# 19  [0.19020000000000004, 0.38820401785714287, 0.5...
# 20  [0.4374035714285715, 0.7381473214285715, 1.038...
# 21  [0.35540625000000003, 0.6014821428571429, 0.85...
# 22  [0.5011785714285715, 0.738125, 0.9386696428571...
# 23  [0.1464625, 0.21406026785714288, 0.30419107142...
# 24  [0.09013080357142858, 0.2365928571428572, 0.38...
# 25  [0.13232455357142858, 0.26464910714285717, 0.3...
# 26  [0.13232455357142858, 0.26464910714285717, 0.3...
# 27  [0.10794241071428572, 0.03598080357142857, 0.1...
# 28  [0.10794241071428572, 0.03598080357142857, 0.1...
# 29  [-0.05996785714285715, 0.023987187500000003, 0...
# 30  [0.0343, 0.0552, 0.0853, 0.121, 0.156, 0.195, ...
# 31  [0.0281, 0.0583, 0.0916, 0.12, 0.146, 0.171, 0...
# 32  [0.215363, 0.739732, 2.53133, 4.41032, 5.39351...
# 33  [0.236892, 0.445177, 1.16471, 1.97891, 3.13395...
# 34  [-0.00926255, 0.142217, 0.350502, 0.767072, 2....
# 35  [0.196164, 0.417705, 1.1505, 2.12187, 2.75241,...
# 36  [-0.00926255, 0.104347, 0.293697, 1.08897, 1.4...
# 37  [-0.0225585, 0.234963, 0.462188, 1.23475, 2.09...
# 38  [0.0286075, 0.123282, 0.369437, 0.691332, 1.33...
# 39  [0.0286075, 0.142217, 0.274762, 1.25938, 2.262...
# 40  [0.255827, 0.445177, 0.653462, 2.50909, 4.2321...
# 41  [0.236892, 0.558787, 1.58128, 2.75525, 4.21324...
# 42  [0.217957, 0.426242, 1.33512, 2.20613, 3.60732...
# 43  [0.144165, 0.345095, 0.633309, 0.806261, 1.065...
# 44  [0.220994, 0.331492, 0.552486, 0.883978, 1.325...
# 45  [0.110497, 0.276243, 0.497238, 0.773481, 1.215...
# 46  [0.0181814, 0.0719223, 0.107263, 0.250961, 0.3...
# 47  [0.271552, 0.270749, 0.306163, 0.378377, 0.432...
# 48                              [0.0727985, 0.781726]
# 49  [1.09807, 2.07471, 3.17483, 4.03156, 4.52091, ...

# %% [markdown]
# # Построение изотерм адсорбции с помощью выбранного уравнения
#
# Для построения изотерм выбрали 3 уравнения:
#
# - `freundlich_langmuir_model` (`FL`) - уравнение Фрейндлиха-Лангмюира.
# - `langmuir_model` (`L`) - уравнение Лангмюира.
# - `freundlich_model` (`F`) - уравнение Фрейндлиха.
#
# Также расчет R^2

# %%
def freundlich_langmuir_model(p, g_inf, K, n):
      return (g_inf * (K*p)**(1/n)/(1 + (K*p)**(1/n)))

# %%
def langmuir_model(p, g_inf, K):
    return (g_inf * (K*p))/(1 + (K*p))

# %%
def freundlich_model(p, K, n):
    return (K*(p**(1/n)))

# %%
eq_drpdown = widgets.Dropdown(
    options=['FL', 'L', 'F'],
    value='FL',
    description='Equation:',
    disabled=False,
)
eq_drpdown
# Out:
# Dropdown(description='Equation:', options=('FL', 'L', 'F'), value='FL')

# %% [markdown]
# Рассчитываются коэффициенты по уравнению адсорбции Ленгмюра-Фрейндлиха.
# В нем константы `K` и `n` находятся графическим способом, следовательно, для определения допустимых значений были выделены следующие критерии:
# - Для константы `n` (тангенс угла наклона прямой по зависимости lgA от lgP) 1 < `n` < 10 (по найденным критериям для `n`).
# - Константа `K` так же находится графически, как точка пересечения прямой по зависимости lgA от lgP с осью y (при P=1) для этого на диапазон значения влияют исходные данные в которых выбирается координаты точки при которых lgP=0, либо ближайшее к нему значение.
# - Минимальное значение `g_inf` (предельная адсорбция) принимает значение максимальной адсорбции по каждому конкретному случаю, максимальное значение не ограничено.

# %%
df_iso = df_prep.copy()

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

def fit_isotherm(pressure, adsorption, model, model_parameters_bounds=([0.0, 2.0, 1.11], [np.inf, 2.50, 10.0])):
    """
    curve_fit function from SciPy
    https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.curve_fit.html
    """
    B = adsorption[find_nearest(pressure, 1.0)]
    if eq_drpdown.value == 'FL':
        curve = [np.nan, np.nan, np.nan]
        model_parameters_bounds=([np.max(adsorption), B - (B/3), 1.11], 
                                 [np.inf, B + (B/3), 10.0])
    elif eq_drpdown.value == 'L':
        curve = [np.nan, np.nan]
        # 1-ый вариант
#         model_parameters_bounds=([np.max(adsorption), B - (B/3)],
#                                  [np.inf, B + (B/3)])
        # нужный вариант
        model_parameters_bounds=([0.0, 0.0],
                                 [np.inf, np.inf])
    elif eq_drpdown.value == 'F':
        curve = [np.nan, np.nan]
        model_parameters_bounds=([B - (B/3), 1.11],
                                 [B + (B/3), 10.0])
    try:
        curve, _ = curve_fit(f=model, xdata=pressure, ydata=adsorption,
                             bounds=model_parameters_bounds)
    except RuntimeError:
        pass
    except ValueError:
        pass
    finally:
        try:
            res = adsorption - model(np.array(pressure), *curve)
        except TypeError:
            curve = np.append(curve, np.nan)
        else:
            ss_res = np.sum(pow(res, 2))
            ss_tot = np.sum((adsorption-np.mean(adsorption))**2)
            r_squared = 1 - (ss_res / ss_tot)
            if r_squared <= 0:
                r_squared = 0
            curve = np.append(curve, r_squared)
        return curve

# %%
# %%time
if eq_drpdown.value == 'FL':
    df_iso['g_inf'], df_iso['K'], df_iso['n'], df_iso['R^2'] = \
    zip(*df_iso[['pressure', 'adsorption']].apply(lambda data: fit_isotherm(data[0], data[1], freundlich_langmuir_model), axis=1))
elif eq_drpdown.value == 'L':
    df_iso['g_inf'], df_iso['K'], df_iso['R^2'] = \
    zip(*df_iso[['pressure', 'adsorption']].apply(lambda data: fit_isotherm(data[0], data[1], langmuir_model), axis=1))
elif eq_drpdown.value == 'F':
    df_iso['K'], df_iso['n'], df_iso['R^2'] = \
    zip(*df_iso[['pressure', 'adsorption']].apply(lambda data: fit_isotherm(data[0], data[1], freundlich_model), axis=1))
# Out:
# D:\Anaconda\lib\site-packages\scipy\optimize\minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: divide by zero encountered in double_scalars
# Wall time: 22.2 s

# %%
df_iso = df_iso.dropna()
df_iso.reset_index(inplace=True, drop=True)
df_iso['doi'] = "http://dx.doi.org/"+ df_iso['doi']
# Saving to excel
if eq_drpdown.value == 'FL':
    df_iso.to_excel("CO2_mmol_g_FL.xlsx")
elif eq_drpdown.value == 'L':
    df_iso.to_excel("CO2_mmol_g_L.xlsx")
elif eq_drpdown.value == 'F':
    df_iso.to_excel("CO2_mmol_g_F.xlsx")
df_iso['ads_units'].value_counts()
# Out:
# mmol/g    1954
# Name: ads_units, dtype: int64

# %%
df_iso.head(50)
# Out:
#                                          doi category       adsorbent  \
# 0   http://dx.doi.org/10.1002/adfm.201200084           NH2-MIL-53(Al)
# 1   http://dx.doi.org/10.1002/adfm.201200084           NH2-MIL-53(Al)
# 2   http://dx.doi.org/10.1002/adfm.201300071                     CCT1
# 3   http://dx.doi.org/10.1002/adfm.201300071                     CCT1
# 4   http://dx.doi.org/10.1002/adfm.201300071                       CT
# 5   http://dx.doi.org/10.1002/adfm.201300071                     CCT1
# 6   http://dx.doi.org/10.1002/adfm.201300071                     CCT1
# 7   http://dx.doi.org/10.1002/adfm.201300071                     CCT1
# 8   http://dx.doi.org/10.1002/adfm.201300071                     CCT1
# 9   http://dx.doi.org/10.1002/adfm.201300071                       CT
# 10  http://dx.doi.org/10.1002/adfm.201300071                     CCT1
# 11  http://dx.doi.org/10.1002/adfm.201301178             Zn(OPE) 2H2O
# 12  http://dx.doi.org/10.1002/adma.200601983                    CUK-1
# 13  http://dx.doi.org/10.1002/adma.200601983                  CMS-T3A
# 14  http://dx.doi.org/10.1002/adma.200601983                  CMS-T3A
# 15  http://dx.doi.org/10.1002/adma.200601983                    CUK-1
# 16  http://dx.doi.org/10.1002/adma.200602645               MIL-53(Cr)
# 17  http://dx.doi.org/10.1002/adma.200702605             Zn(2-2H)*H2O
# 18  http://dx.doi.org/10.1002/adma.200802485                    CPP-8
# 19  http://dx.doi.org/10.1002/adma.200802485                    CPP-7
# 20  http://dx.doi.org/10.1002/adma.200802485                    CPP-6
# 21  http://dx.doi.org/10.1002/adma.201400428           Cu3(BTC)2@TiO2
# 22  http://dx.doi.org/10.1002/adma.201400428                    CuBTC
# 23  http://dx.doi.org/10.1002/adma.201403827      exp           CuBTC
# 24  http://dx.doi.org/10.1002/adma.201403827      exp           CuBTC
# 25  http://dx.doi.org/10.1002/adma.201403827      exp   HKUST-1@PS_63
# 26  http://dx.doi.org/10.1002/adma.201403827      exp   HKUST-1@PS_63
# 27  http://dx.doi.org/10.1002/adma.201403827      exp              PS
# 28  http://dx.doi.org/10.1002/adma.201605826      exp          DATPIM
# 29  http://dx.doi.org/10.1002/adma.201605826      exp           PIM-1
# 30       http://dx.doi.org/10.1002/Aic.11865                  Soc-MOF
# 31       http://dx.doi.org/10.1002/Aic.13970                 ED-ZIF-8
# 32       http://dx.doi.org/10.1002/Aic.13970                    ZIF-8
# 33       http://dx.doi.org/10.1002/Aic.13970                    ZIF-8
# 34       http://dx.doi.org/10.1002/Aic.13970                    ZIF-8
# 35       http://dx.doi.org/10.1002/Aic.13970                 ED-ZIF-8
# 36       http://dx.doi.org/10.1002/Aic.13970                    ZIF-8
# 37       http://dx.doi.org/10.1002/Aic.13970                    ZIF-8
# 38       http://dx.doi.org/10.1002/Aic.13970                 ED-ZIF-8
# 39       http://dx.doi.org/10.1002/Aic.13970                 ED-ZIF-8
# 40       http://dx.doi.org/10.1002/Aic.13970                 ED-ZIF-8
# 41       http://dx.doi.org/10.1002/Aic.14467                      DDR
# 42       http://dx.doi.org/10.1002/Aic.14467                  MOF-177
# 43       http://dx.doi.org/10.1002/Aic.14467                  MOF-177
# 44       http://dx.doi.org/10.1002/Aic.14467                Mg-MOF-74
# 45       http://dx.doi.org/10.1002/Aic.14467                Mg-MOF-74
# 46       http://dx.doi.org/10.1002/Aic.14467                    ZIF-8
# 47       http://dx.doi.org/10.1002/Aic.14467                    ZIF-8
# 48       http://dx.doi.org/10.1002/Aic.14467                      DDR
# 49       http://dx.doi.org/10.1002/Aic.14467                      DDR
#
#          adsorbate  temperature p_units ads_units  \
# 0   Carbon Dioxide          273     bar    mmol/g
# 1   Carbon Dioxide          298     bar    mmol/g
# 2   Carbon Dioxide          273     bar    mmol/g
# 3   Carbon Dioxide          273     bar    mmol/g
# 4   Carbon Dioxide          273     bar    mmol/g
# 5   Carbon Dioxide          273     bar    mmol/g
# 6   Carbon Dioxide          273     bar    mmol/g
# 7   Carbon Dioxide          273     bar    mmol/g
# 8   Carbon Dioxide          273     bar    mmol/g
# 9   Carbon Dioxide          273     bar    mmol/g
# 10  Carbon Dioxide          273     bar    mmol/g
# 11  Carbon Dioxide          195     bar    mmol/g
# 12  Carbon Dioxide          196     bar    mmol/g
# 13  Carbon Dioxide          196     bar    mmol/g
# 14  Carbon Dioxide          298     bar    mmol/g
# 15  Carbon Dioxide          298     bar    mmol/g
# 16  Carbon Dioxide          304     bar    mmol/g
# 17  Carbon Dioxide          258     bar    mmol/g
# 18  Carbon Dioxide          195     bar    mmol/g
# 19  Carbon Dioxide          195     bar    mmol/g
# 20  Carbon Dioxide          195     bar    mmol/g
# 21  Carbon Dioxide          298     bar    mmol/g
# 22  Carbon Dioxide          298     bar    mmol/g
# 23  Carbon Dioxide          295     bar    mmol/g
# 24  Carbon Dioxide          295     bar    mmol/g
# 25  Carbon Dioxide          295     bar    mmol/g
# 26  Carbon Dioxide          295     bar    mmol/g
# 27  Carbon Dioxide          295     bar    mmol/g
# 28  Carbon Dioxide          298     bar    mmol/g
# 29  Carbon Dioxide          298     bar    mmol/g
# 30  Carbon Dioxide          298     bar    mmol/g
# 31  Carbon Dioxide          328     bar    mmol/g
# 32  Carbon Dioxide          298     bar    mmol/g
# 33  Carbon Dioxide          298     bar    mmol/g
# 34  Carbon Dioxide          308     bar    mmol/g
# 35  Carbon Dioxide          298     bar    mmol/g
# 36  Carbon Dioxide          318     bar    mmol/g
# 37  Carbon Dioxide          328     bar    mmol/g
# 38  Carbon Dioxide          298     bar    mmol/g
# 39  Carbon Dioxide          308     bar    mmol/g
# 40  Carbon Dioxide          318     bar    mmol/g
# 41  Carbon Dioxide          298     bar    mmol/g
# 42  Carbon Dioxide          298     bar    mmol/g
# 43  Carbon Dioxide          298     bar    mmol/g
# 44  Carbon Dioxide          298     bar    mmol/g
# 45  Carbon Dioxide          298     bar    mmol/g
# 46  Carbon Dioxide          298     bar    mmol/g
# 47  Carbon Dioxide          298     bar    mmol/g
# 48  Carbon Dioxide          298     bar    mmol/g
# 49  Carbon Dioxide          313     bar    mmol/g
#
#                                              pressure  \
# 0   [0.42318, 0.676969, 1.01993, 1.36288, 1.70644,...
# 1   [0.678881, 1.35654, 1.86693, 2.54398, 3.22102,...
# 2   [0.0126608, 0.0422383, 0.0746326, 0.112661, 0....
# 3   [0.0182946, 0.0408298, 0.0816749, 0.129562, 0....
# 4   [0.0408298, 0.0999848, 0.161957, 0.218295, 0.2...
# 5   [0.0112524, 0.0816749, 0.161957, 0.221112, 0.2...
# 6   [0.0112524, 0.078858, 0.130971, 0.192943, 0.28...
# 7   [0.0689988, 0.15914, 0.221112, 0.280266, 0.339...
# 8   [0.0422383, 0.0999848, 0.161957, 0.250689, 0.3...
# 9   [0.02252, 0.0661819, 0.160548, 0.253506, 0.345...
# 10  [0.0140693, 0.0422383, 0.0802664, 0.112661, 0....
# 11  [0.011591, 0.0125803, 0.0222627, 0.0260398, 0....
# 12  [0.00302147, 0.00604294, 0.0120859, 0.0241718,...
# 13  [0.00381528, 0.0185494, 0.0623471, 0.120634, 0...
# 14  [0.00848082, 0.090245, 0.229363, 0.359861, 0.5...
# 15  [0.02517, 0.135289, 0.239115, 0.364965, 0.5096...
# 16  [0.14003, 0.273866, 0.325569, 0.365962, 0.4561...
# 17  [0.041306, 0.108469, 0.18258, 0.298378, 0.4327...
# 18  [0.00953647, 0.0190729, 0.0309935, 0.0667553, ...
# 19  [0.00953647, 0.0190729, 0.0309935, 0.0429141, ...
# 20  [0.00953647, 0.0166888, 0.0286094, 0.04053, 0....
# 21  [2.39868, 4.16471, 5.67958, 7.57237, 9.21284, ...
# 22  [1.01098, 2.52784, 4.29665, 5.93908, 7.58109, ...
# 23  [0.006753, 0.035533, 0.053299, 0.05566, 0.0843...
# 24  [0.006753, 0.035533, 0.053299, 0.05566, 0.0843...
# 25  [0.002262, 0.006628, 0.033112, 0.055237, 0.057...
# 26  [0.002262, 0.006628, 0.033112, 0.055237, 0.057...
# 27  [0.002268, 0.006582, 0.028608, 0.055027, 0.081...
# 28  [0.008999, 0.012932, 0.020798, 0.030931, 0.041...
# 29  [0.010119, 0.021332, 0.032664, 0.04213, 0.0527...
# 30  [0.251391, 0.316938, 1.10349, 2.08669, 3.06988...
# 31  [0.437049, 1.18705, 3.14538, 5.02038, 8.14538,...
# 32  [0.103716, 0.395382, 1.02038, 1.93705, 4.97872...
# 33  [0.395382, 0.895382, 2.56205, 5.02038, 7.18705...
# 34  [0.103716, 0.437049, 1.02038, 3.68705, 4.93705...
# 35  [0.174459, 0.624459, 1.17446, 3.12446, 5.02446...
# 36  [0.0203823, 0.603716, 1.39538, 2.52038, 5.1037...
# 37  [0.0203823, 0.520382, 1.31205, 5.14538, 10.062...
# 38  [0.395382, 0.562049, 0.937049, 2.89538, 4.9370...
# 39  [0.395382, 0.937049, 2.93705, 5.02038, 8.02038...
# 40  [0.520382, 1.06205, 3.06205, 5.06205, 8.10372,...
# 41  [0.0594233, 0.29862, 0.437467, 0.516775, 0.615...
# 42  [2.43392e-05, 0.044273, 0.100545, 0.197123, 0....
# 43  [0.0646206, 0.108796, 0.161052, 0.189262, 0.22...
# 44  [0.00420168, 0.012605, 0.0336134, 0.0588235, 0...
# 45  [0.00420168, 0.0504202, 0.0966387, 0.193277, 0...
# 46  [-2.22045e-16, 0.0441767, 0.0963855, 0.196787,...
# 47  [0.00401606, 0.064257, 0.13253, 0.26506, 0.666...
# 48  [0.158963, 0.378043, 0.577239, 0.796435, 0.975...
# 49      [0.109756, 0.260163, 0.5, 0.756098, 0.995935]
#
#                                            adsorption      g_inf           K  \
# 0   [0.3864669642857143, 0.6226428571428572, 0.772...   3.235962    0.206426
# 1   [0.09775803571428571, 0.17922321428571428, 0.2...   2.743010    0.048580
# 2   [0.098115625, 0.2917776785714286, 0.4275924107...   1.801740    3.012629
# 3   [0.09057053571428571, 0.2188401785714286, 0.33...   1.954641    2.058002
# 4   [0.18865892857142857, 0.34710982142857144, 0.4...   1.767504    2.060469
# 5   [0.098115625, 0.31944375, 0.45777232142857144,...   1.592324    2.275958
# 6   [0.098115625, 0.26159642857142856, 0.349625, 0...   1.224797    2.685078
# 7   [0.08554017857142858, 0.17859866071428573, 0.2...   3.171433    0.340284
# 8   [0.030208303571428573, 0.07547991071428571, 0....   8.110181    0.089948
# 9   [0.04278375, 0.098115625, 0.16853839285714287,...   1.022613    1.104474
# 10  [0.1081763392857143, 0.3722607142857143, 0.535...   2.194205    3.202247
# 11  [0.0010337410714285715, 0.08425, 0.16824151785...   3.090258    2.224711
# 12  [1.8130803571428573, 3.2840714285714285, 5.644...   7.113402  181.221395
# 13  [2.2269642857142857, 4.661071428571429, 6.9916...  13.581011   18.366087
# 14  [0.01936433035714286, 0.4352419642857143, 0.77...   2.972230    1.474605
# 15  [0.26396294642857143, 1.0234375, 1.63455803571...   6.999908    1.289728
# 16  [0.204187, 0.996459, 0.587236, 1.25191, 1.6863...  14.748105    0.089171
# 17  [0.19020000000000004, 0.38820401785714287, 0.5...   2.019937    1.963051
# 18  [0.4374035714285715, 0.7381473214285715, 1.038...   2.939567    9.377564
# 19  [0.35540625000000003, 0.6014821428571429, 0.85...   2.732759    9.845065
# 20  [0.5011785714285715, 0.738125, 0.9386696428571...   2.553153   11.994783
# 21  [0.1464625, 0.21406026785714288, 0.30419107142...   6.372134    0.008372
# 22  [0.09013080357142858, 0.2365928571428572, 0.38...  10.018150    0.008658
# 23  [0.13232455357142858, 0.26464910714285717, 0.3...  10.305767    0.669452
# 24  [0.13232455357142858, 0.26464910714285717, 0.3...  10.305767    0.669452
# 25  [0.10794241071428572, 0.03598080357142857, 0.1...   9.683862    0.403914
# 26  [0.10794241071428572, 0.03598080357142857, 0.1...   9.683862    0.403914
# 27  [-0.05996785714285715, 0.023987187500000003, 0...   0.401261    1.066144
# 28  [0.0343, 0.0552, 0.0853, 0.121, 0.156, 0.195, ...   2.099122    1.709188
# 29  [0.0281, 0.0583, 0.0916, 0.12, 0.146, 0.171, 0...   3.513249    0.754690
# 30  [0.215363, 0.739732, 2.53133, 4.41032, 5.39351...   9.885513    0.350596
# 31  [0.236892, 0.445177, 1.16471, 1.97891, 3.13395...  28.435138    0.015299
# 32  [-0.00926255, 0.142217, 0.350502, 0.767072, 2....   7.388872    0.078750
# 33  [0.196164, 0.417705, 1.1505, 2.12187, 2.75241,...   7.197732    0.087191
# 34  [-0.00926255, 0.104347, 0.293697, 1.08897, 1.4...   8.666675    0.043820
# 35  [-0.0225585, 0.234963, 0.462188, 1.23475, 2.09...  14.038629    0.035494
# 36  [0.0286075, 0.123282, 0.369437, 0.691332, 1.33...   8.271914    0.041580
# 37  [0.0286075, 0.142217, 0.274762, 1.25938, 2.262...   7.854903    0.039319
# 38  [0.255827, 0.445177, 0.653462, 2.50909, 4.2321...  15.186440    0.077976
# 39  [0.236892, 0.558787, 1.58128, 2.75525, 4.21324...  19.978585    0.033467
# 40  [0.217957, 0.426242, 1.33512, 2.20613, 3.60732...  23.051519    0.023273
# 41  [0.144165, 0.345095, 0.633309, 0.806261, 1.065...   2.683575    0.918230
# 42  [0.0181814, 0.0719223, 0.107263, 0.250961, 0.3...  14.609347    0.085698
# 43  [0.271552, 0.270749, 0.306163, 0.378377, 0.432...   6.027941    0.313681
# 44  [1.09807, 2.07471, 3.17483, 4.03156, 4.52091, ...   7.915649   16.584168
# 45  [0.488317, 2.07932, 4.03618, 5.99918, 6.9876, ...  10.527666    6.241899
# 46  [0.0462428, 0.0924855, 0.208092, 0.393064, 0.5...  20.508531    0.093921
# 47  [0.0693642, 0.138728, 0.184971, 0.300578, 0.64...   3.866158    0.326542
# 48  [0.259197, 0.489144, 0.690305, 0.89135, 1.0637...   3.179776    0.504208
# 49   [0.108696, 0.271739, 0.48913, 0.48913, 0.706522]   1.428947    0.882278
#
#          R^2
# 0   0.973719
# 1   0.995877
# 2   0.984611
# 3   0.991906
# 4   0.992460
# 5   0.988556
# 6   0.986386
# 7   0.998344
# 8   0.999719
# 9   0.994081
# 10  0.986533
# 11  0.988812
# 12  0.941035
# 13  0.960656
# 14  0.995722
# 15  0.999723
# 16  0.940902
# 17  0.993974
# 18  0.941392
# 19  0.958899
# 20  0.925140
# 21  0.999780
# 22  0.999812
# 23  0.997781
# 24  0.997781
# 25  0.995642
# 26  0.995642
# 27  0.938975
# 28  0.998600
# 29  0.999594
# 30  0.993692
# 31  0.999214
# 32  0.995863
# 33  0.997273
# 34  0.996056
# 35  0.999174
# 36  0.997044
# 37  0.998585
# 38  0.996447
# 39  0.998616
# 40  0.996861
# 41  0.974832
# 42  0.998880
# 43  0.981154
# 44  0.966727
# 45  0.996140
# 46  0.998644
# 47  0.979818
# 48  0.999056
# 49  0.946285

# %% [markdown]
# # Поиск ref кода

# %%
conq = pd.read_excel("conquest.xlsx")

# %%
df_fin = pd.merge(df_iso,conq,on='doi', how='left')
df_fin.to_excel("CO2_mmol_g_Langmuer_ref.xlsx")

# %% [markdown]
# # Распределение R^2

# %%
df_iso.hist(column='R^2')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000017D283CB288>]],
#       dtype=object)

# %%
from scipy.stats import logistic,uniform,norm,pearsonr
from numpy import sqrt,pi,e
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)
n=df_iso['R^2'].size# объём выборки
x=np.array(df_iso['R^2'])
x.sort()#сортировка 
print("Математическое ожидание по выборке(общее для сравниваемых распределений) -%s"%str(round(np.mean(x),3)))
print("СКО по выборке(общее для сравниваемых распределений) -%s"%str(round(np.std(x),3)))
print("Энтропийное значение погрешности-%s"%str(round(np.std(x)*sqrt(np.pi*np.e*0.5),3)))      
pu=uniform.cdf(x/(np.max(x)))#равномерное интегральное  распределение 
ax.plot(x,pu, lw=5, alpha=0.6, label='uniform cdf')
pn=norm.cdf(x, np.mean(x), np.std(x))#нормальное интегральное  распределение 
ax.plot(x,pn, lw=5, alpha=0.6, label='norm cdf')
pl=logistic.cdf(x, np.mean(x), np.std(x))# логистическое  интегральное  распределение 
ax.plot(x,pl, lw=5, alpha=0.6, label='logistic cdf')
p=np.arange(0,n,1)/n
ax.plot(x,p, lw=5, alpha=0.6, label='test')
ax.legend(loc='best', frameon=False)
plt.show()
print("Корреляция между нормальным  распределением и тестовым - %s"%str(round(pearsonr(pn,p)[0],3)))
print("Корреляция между логистическим  распределением и тестовым - %s"%str(round(pearsonr(pl,p)[0],3)))
print("Корреляция между равномерным  распределением и тестовым - %s"%str(round(pearsonr(pu,p)[0],3)))
print('Взвешенная сумма  квадратов отклонения нормального распределения от теста -%i'%round(n*sum(((pn-p)/pn)**2)))
print('Взвешенная сумма квадратов отклонения логистического распределения от теста -%i'%round(n*sum(((pl-p)/pl)**2)))
print('Взвешенная сумма квадратов отклонения равномерного распределения от теста -%i'%round(n*sum(((pu-p)/pu)**2)))
# Out:
# Математическое ожидание по выборке(общее для сравниваемых распределений) -0.783
# СКО по выборке(общее для сравниваемых распределений) -0.246
# Энтропийное значение погрешности-0.508
# Корреляция между нормальным  распределением и тестовым - 0.943
# Корреляция между логистическим  распределением и тестовым - 0.932
# Корреляция между равномерным  распределением и тестовым - 0.901
# Взвешенная сумма  квадратов отклонения нормального распределения от теста -5678013
# Взвешенная сумма квадратов отклонения логистического распределения от теста -417500
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: divide by zero encountered in true_divide
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in true_divide
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-c7f88b3c3c19> in <module>
#      25 print('Взвешенная сумма  квадратов отклонения нормального распределения от теста -%i'%round(n*sum(((pn-p)/pn)**2)))
#      26 print('Взвешенная сумма квадратов отклонения логистического распределения от теста -%i'%round(n*sum(((pl-p)/pl)**2)))
# ---> 27 print('Взвешенная сумма квадратов отклонения равномерного распределения от теста -%i'%round(n*sum(((pu-p)/pu)**2)))
#
# ValueError: cannot convert float NaN to integer

# %% [markdown]
# # Удаляем дубликаты из датасета

# %%
df_set = df_iso.copy()
if eq_drpdown.value == 'FL':
    df_set = df_set.drop_duplicates(subset=['g_inf', 'K', 'n', 'adsorbent'])
elif eq_drpdown.value == 'L':
    df_set = df_set.drop_duplicates(subset=['g_inf', 'K', 'adsorbent'])
elif eq_drpdown.value == 'F':
    df_set = df_set.drop_duplicates(subset=['K', 'n', 'adsorbent'])
df_set['ads_units'].value_counts()
# Out:
# mmol/g    1928
# Name: ads_units, dtype: int64

# %% [markdown]
# # Построение графиков изотерм выбранного MOF из датасета

# %%
df_set_drpdwn = widgets.Dropdown(
    options=list(df_set.drop_duplicates(subset=['adsorbent'])['adsorbent']),
    description='MOF:',
    disabled=False,
)
df_set_drpdwn
# Out:
# Dropdown(description='MOF:', options=('NH2-MIL-53(Al)', 'CCT1', 'CT', 'Zn(OPE) 2H2O', 'CUK-1', 'CMS-T3A', 'MIL…

# %%
subset = df_set[df_set['adsorbent']== df_set_drpdwn.value]
subset
# Out:
#                                             doi category       adsorbent  \
# 0        https://doi.org/10.1002/adfm.201200084           NH2-MIL-53(Al)
# 1        https://doi.org/10.1002/adfm.201200084           NH2-MIL-53(Al)
# 147      https://doi.org/10.1002/ceat.201400741      exp  NH2-MIL-53(Al)
# 277      https://doi.org/10.1002/cssc.201100378           NH2-MIL-53(Al)
# 545   https://doi.org/10.1016/j.ces.2014.10.028      exp  NH2-MIL-53(Al)
# 546   https://doi.org/10.1016/j.ces.2014.10.028      exp  NH2-MIL-53(Al)
# 547   https://doi.org/10.1016/j.ces.2014.10.028      exp  NH2-MIL-53(Al)
# 548   https://doi.org/10.1016/j.ces.2014.10.028      exp  NH2-MIL-53(Al)
# 1608          https://doi.org/10.1021/Ie3004336           NH2-MIL-53(Al)
#
#            adsorbate  temperature p_units ads_units  \
# 0     Carbon Dioxide          273     bar    mmol/g
# 1     Carbon Dioxide          298     bar    mmol/g
# 147   Carbon Dioxide          298     bar    mmol/g
# 277   Carbon Dioxide          283     bar    mmol/g
# 545   Carbon Dioxide          257     bar    mmol/g
# 546   Carbon Dioxide          263     bar    mmol/g
# 547   Carbon Dioxide          273     bar    mmol/g
# 548   Carbon Dioxide          298     bar    mmol/g
# 1608  Carbon Dioxide          308     bar    mmol/g
#
#                                                pressure  \
# 0     [0.42318, 0.676969, 1.01993, 1.36288, 1.70644,...
# 1     [0.678881, 1.35654, 1.86693, 2.54398, 3.22102,...
# 147   [0.22898, 0.231476, 0.233616, 0.24503, 0.36629...
# 277   [0.076979, 0.331972, 0.844845, 1.78752, 2.2163...
# 545   [1.01761, 1.64384, 2.19178, 2.818, 3.60078, 4....
# 546   [0.156556, 0.234834, 0.391389, 0.626223, 1.565...
# 547   [0.078278, 0.156556, 0.234834, 0.313112, 0.547...
# 548   [0, 0.156556, 0.234834, 0.313112, 0.704501, 1....
# 1608  [0.0324133, 0.0870352, 0.135102, 0.18317, 0.23...
#
#                                              adsorption      g_inf         K  \
# 0     [0.3864669642857143, 0.6226428571428572, 0.772...   3.235962  0.206426
# 1     [0.09775803571428571, 0.17922321428571428, 0.2...   2.743010  0.048580
# 147   [2.34701, 2.13272, 1.94905, 0.969459, 2.56133,...  10.808187  0.170756
# 277   [0.835821, 1.10448, 1.37313, 1.64179, 1.73134,...  14.263024  0.044365
# 545   [2.35294, 2.41486, 2.47678, 2.50774, 2.60062, ...  31.036412  0.023320
# 546   [2.01238, 1.9195, 2.2291, 2.29102, 2.3839, 2.4...  23.785644  0.029797
# 547   [1.23839, 1.64087, 1.88854, 2.04334, 2.13622, ...  45.468685  0.008316
# 548   [1.30031, 1.11455, 1.60991, 1.76471, 1.95046, ...  10.659401  0.032265
# 1608  [0.09719017857142857, 0.21179866071428574, 0.3...   1.469748  1.767996
#
#            R^2
# 0     0.973719
# 1     0.995877
# 147   0.644325
# 277   0.936987
# 545   0.931386
# 546   0.872740
# 547   0.824477
# 548   0.529785
# 1608  0.995290

# %%
subset_drpdwn = widgets.Dropdown(
    options=subset.index.values.tolist(),
    description='Choose',
    disabled=False,
)
subset_drpdwn
# Out:
# Dropdown(description='Choose', options=(0, 1, 147, 277, 545, 546, 547, 548, 1608), value=0)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mof_ind = subset_drpdwn.value
plt.subplot(121)
plt.plot(df_set.loc[mof_ind, 'pressure'], 1000*np.array(df_set.loc[mof_ind, 'adsorption']), 'ro--')
plt.title(df_set.loc[mof_ind, 'adsorbent'])
plt.ylabel(df_set.loc[mof_ind, 'doi'])
plt.subplot(122)
plt.plot(df_set.loc[mof_ind, 'pressure'], df_set.loc[mof_ind, 'adsorption'], 'bo--')
plt.title(df_set.loc[mof_ind, 'adsorbent'])
plt.show()
